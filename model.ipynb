# %%
import torch

# %%
from ultralytics import YOLO
model=YOLO('C:/Users/world/Desktop/New folder/best.pt')

# %%
type(model)
# Out:
# ultralytics.models.yolo.model.YOLO

# %%
import matplotlib.pyplot as plt
pic=plt.imread('C:/Users/world/Documents/Moeez Documents JPEG/cnic_front.jpg')
res=model.predict(source=pic)
plt.imshow(res[0].plot())
# Out:
# 0: 416x640 29 texts, 401.0ms
# Speed: 8.0ms preprocess, 401.0ms inference, 13.0ms postprocess per image at shape (1, 3, 416, 640)

# %%
from paddleocr import PaddleOCR

def function_ocr(img_path):
    ocr = PaddleOCR(use_angle_cls=True, lang='en')
    result = ocr.ocr(img_path, cls=True)
    text = ""
    for line in result:
        for word_info in line:
            text += word_info[1][0] + " "
    return text.strip()

image_path = 'C:/Users/world/Documents/Moeez Documents JPEG/cnic_front.jpg'
recognized_text = function_ocr(image_path)
print(recognized_text)
# Out:
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/english/en_PP-OCRv3_det_infer.tar to C:\Users\world/.paddleocr/whl\det\en\en_PP-OCRv3_det_infer\en_PP-OCRv3_det_infer.tar
# 100%|██████████| 4.00M/4.00M [00:19<00:00, 201kiB/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv4/english/en_PP-OCRv4_rec_infer.tar to C:\Users\world/.paddleocr/whl\rec\en\en_PP-OCRv4_rec_infer\en_PP-OCRv4_rec_infer.tar
# 100%|██████████| 10.2M/10.2M [00:50<00:00, 202kiB/s]
# download https://paddleocr.bj.bcebos.com/dygraph_v2.0/ch/ch_ppocr_mobile_v2.0_cls_infer.tar to C:\Users\world/.paddleocr/whl\cls\ch_ppocr_mobile_v2.0_cls_infer\ch_ppocr_mobile_v2.0_cls_infer.tar
# 100%|██████████| 2.19M/2.19M [00:05<00:00, 386kiB/s]
# ...
