# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR='/content/gdrive/My Drive/Colab Notebooks/shirts_dataset_yolo'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 631.3 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.4/825.4 kB 5.4 MB/s eta 0:00:00
# ...

# %%
import os
from ultralytics import YOLO

# %%
model=YOLO('yolov5lu.pt')

# %%
# Assuming you have created a YAML file named 'dataset.
model.train(data=os.path.join(ROOT_DIR,'config.yaml'),augment=True, epochs=30, mixup=True,mosaic=True)
# Out:
# Ultralytics YOLOv8.2.69 🚀 Python-3.10.12 torch-2.3.0+cpu CPU (Intel Xeon 2.00GHz)
# ...

# %%
model.save('shirts_detection')

# %%
model.val()
# Out:
# Ultralytics YOLOv8.2.68 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv5n summary (fused): 193 layers, 2,503,724 parameters, 0 gradients, 7.1 GFLOPs
# val: Scanning /content/gdrive/My Drive/Colab Notebooks/shirts_dataset_yolo/data/labels.cache... 420 images, 0 backgrounds, 0 corrupt: 100%|██████████| 420/420 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 27/27 [00:11<00:00,  2.29it/s]
#                    all        420        487      0.983      0.983      0.994      0.907
#             Blue shirt         93         93      0.979       0.98      0.994      0.947
# ...

# %%
import matplotlib.pyplot as plt

# %%
pic=plt.imread('/content/48-assfmmopd44109-allen-solly-original-imagkc43caqruuzn.webp')
res=model.predict(source=pic,save=True)
plt.imshow(res[0].plot())
# Out:
# 0: 640x448 1 White shirt, 28.5ms
# Speed: 10.1ms preprocess, 28.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to runs/detect/train273

# %%
pic=plt.imread('/content/86f6cca46ca00873a3d34b05aa7577b7.jpg')
res=model.predict(source=pic,save=True)
plt.imshow(res[0].plot())
# Out:
# 0: 640x448 1 Black shirt, 1 White shirt, 19.3ms
# Speed: 3.2ms preprocess, 19.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to runs/detect/train274

# %%
pic=plt.imread('/content/86f6cca46ca00873a3d34b05aa7577b7.jpg')
res=model.predict(source=pic,save=True)
plt.imshow(res[0].plot())
# Out:
# 0: 640x448 1 Black shirt, 1 White shirt, 56.3ms
# Speed: 3.5ms preprocess, 56.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to runs/detect/train275

# %%
pic=plt.imread('/content/3_2.webp')
res=model.predict(source=pic,save=True)
plt.imshow(res[0].plot())
# Out:
# 0: 640x640 1 Black shirt, 13.8ms
# Speed: 5.1ms preprocess, 13.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train276

# %%
pic=plt.imread('/content/26-1-600x600.jpg')
res=model.predict(source=pic,save=True)
plt.imshow(res[0].plot())
# Out:
# 0: 640x640 (no detections), 32.3ms
# Speed: 4.8ms preprocess, 32.3ms inference, 10.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train277

# %%
pic=plt.imread('/content/1_ef307dcc-7da9-4bad-be7d-52abd9face71.webp')
res=model.predict(source=pic,save=True)
plt.imshow(res[0].plot())
# Out:
# 0: 640x544 1 Gray shirt, 29.2ms
# Speed: 3.7ms preprocess, 29.2ms inference, 8.9ms postprocess per image at shape (1, 3, 640, 544)
# Results saved to runs/detect/train278

# %%
# !pip install numpy
# !pip install opencv-python
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-31-e314026fdfb6> in <cell line: 1>()
# ----> 1 get_ipython().system('pip install numpy')
#       2 get_ipython().system('pip install opencv-python')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
#     453   # stack.
# --> 454   result = _run_command(
#     455       shell.var_expand(cmd, depth=2), clear_streamed_output=False
# ...

# %%
from ultralytics import YOLO
import requests
from PIL import Image
from io import BytesIO
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
# Load the YOLO model
# Download the image from the website
image_url = 'https://media.istockphoto.com/id/184380895/photo/male-portrait.webp?b=1&s=170667a&w=0&k=20&c=wc9132Qz8FZfEPZyauy23uYzYVe0CIm6ORma3qRfj_M='
response = requests.get(image_url)
img = Image.open(BytesIO(response.content))
# Convert image to numpy array
img_array = np.array(img)
# Convert the image to RGB
img_rgb = cv2.cvtColor(img_array, cv2.COLOR_RGB2BGR)
# Display the original image
cv2_imshow(img_rgb)
# Save the image to disk
img_path = 'web_image.jpg'
cv2.imwrite(img_path, img_rgb)
# Perform inference on the downloaded image with a lower confidence threshold
results = model(img_path, conf=0.1)
# Display the results
for result in results:
    result.plot()  # Use plot() to show the results in Colab
# Out:
# PRO TIP 💡 Replace 'model=yolov5n.pt' with new 'model=yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
# <PIL.Image.Image image mode=RGB size=464x371>
# image 1/1 /content/web_image.jpg: 512x640 1 person, 118.4ms
# Speed: 2.9ms preprocess, 118.4ms inference, 2.4ms postprocess per image at shape (1, 3, 512, 640)

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode
import cv2
from google.colab.patches import cv2_imshow
def take_photo(filename='photo.jpg', quality=0.8):
    js = Javascript('''
    async function takePhoto(quality) {
        const div = document.createElement('div');
        const capture = document.createElement('button');
        capture.textContent = 'Capture';
        div.appendChild(capture);
        const video = document.createElement('video');
        video.style.display = 'block';
        const stream = await navigator.mediaDevices.getUserMedia({video: true});
        document.body.appendChild(div);
        div.appendChild(video);
        video.srcObject = stream;
        await video.play();
        // Resize video to match webcam resolution
        google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);
        // Wait for Capture button to be clicked.
        await new Promise((resolve) => capture.onclick = resolve);
        const canvas = document.createElement('canvas');
        canvas.width = video.videoWidth;
        canvas.height = video.videoHeight;
        canvas.getContext('2d').drawImage(video, 0, 0);
        stream.getVideoTracks()[0].stop();
        div.remove();
        return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
    display(js)
    data = eval_js('takePhoto({})'.format(quality))
    binary = b64decode(data.split(',')[1])
    with open(filename, 'wb') as f:
        f.write(binary)
    return filename
# Take a photo using the webcam
image_path = take_photo()
print(f"Photo saved at {image_path}")
# Load the captured image
img = plt.imread(image_path)
# Perform inference on the captured image
results = model.predict(img, save=True)
# Display the results
results[0].plot() # Use plot() to show the results in Colab
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-32-b68be321a6b4> in <cell line: 40>()
#      38     return filename
#      39 # Take a photo using the webcam
# ---> 40 image_path = take_photo()
#      41 print(f"Photo saved at {image_path}")
#      42 # Load the captured image
#
# <ipython-input-32-b68be321a6b4> in take_photo(filename, quality)
#      32     ''')
#      33     display(js)
# ---> 34     data = eval_js('takePhoto({})'.format(quality))
#      35     binary = b64decode(data.split(',')[1])
#      36     with open(filename, 'wb') as f:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result, timeout_sec)
#      38   if ignore_result:
#      39     return
# ---> 40   return _message.read_reply_from_input(request_id, timeout_sec)
#      41
#      42
#
# ...

# %%
pic=plt.imread('/content/images_white.jpg')
res=model.predict(source=pic,save=True)
plt.imshow(res[0].plot())
# Out:
# 0: 640x576 2 White shirts, 368.8ms
# Speed: 3.3ms preprocess, 368.8ms inference, 9.2ms postprocess per image at shape (1, 3, 640, 576)
# Results saved to runs/detect/train29
